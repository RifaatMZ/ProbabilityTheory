# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1-  Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Используя математические операции, посчитать коэффициенты линейной регрессии, приняв за X заработную плату (то есть, zp - признак), а за y - значения скорингового балла (то есть, ks - целевая переменная). Произвести расчет как с использованием intercept, так и без.

# %% [markdown]
# ![10.png](attachment:10.png)![11.png](attachment:11.png)

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])
n = zp.size
n
# Out:
# 10

# %%
plt.scatter(zp, ks)
plt.show()

# %%
# с использованием intercept
b = (n *(np.sum(zp * ks)) - (np.sum(zp) * np.sum(ks))) /\
    (n * (np.sum(zp ** 2)) - ((np.sum(zp) ** 2)))
b
# Out:
# 2.6205388824027653

# %%
a = np.mean(ks) - (b * np.mean(zp))
a
# Out:
# 444.17735732435955

# %%
# без intercept
b = np.mean(ks) / np.mean(zp)
b
# Out:
# 7.000986193293885

# %% [markdown]
# #### 2- Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept).

# %%
# model => y_hat = B1 * X
def mse_(B1, y , x , n):
    return (np.sum((B1 * x - y) ** 2) / n)

# %% [markdown]
# ![12.png](attachment:12.png)

# %%
B1 = 0.1
alpha = 1e-6
x = zp
y = ks

for i in range(1000):
    B1 -= alpha * (2 / n) * np.sum((B1 * x - y) * x)
    if i % 100 == 0:
        print('Iteration: {i}, B1 = {B1}, mse = {mse}'.\
              format(i=i, B1=B1, mse= mse_(B1, y=y, x=x, n=n)))
# Out:
# Iteration: 0, B1 = 0.25952808, mse = 493237.7212546963
# Iteration: 100, B1 = 5.54537842245223, mse = 58151.31823171113
# Iteration: 200, B1 = 5.868748638669329, mse = 56522.97550129376
# Iteration: 300, B1 = 5.888531320728348, mse = 56516.88130936019
# Iteration: 400, B1 = 5.8897415574471985, mse = 56516.85850140053
# Iteration: 500, B1 = 5.889815595583751, mse = 56516.858416040064
# Iteration: 600, B1 = 5.889820124983314, mse = 56516.85841572062
# Iteration: 700, B1 = 5.889820402076462, mse = 56516.85841571941
# Iteration: 800, B1 = 5.88982041902807, mse = 56516.8584157194
# Iteration: 900, B1 = 5.889820420065112, mse = 56516.85841571941

# %% [markdown]
# #### 3- В каких случаях для вычисления доверительных интервалов и проверки статистических гипотез используется таблица значений функции Лапласа, а в каких - таблица критических точек распределения Стьюдента?

# %%
#  таблица значений функции Лапласа - когда СКО тзвестно

# %% [markdown]
# #### *4- Произвести вычисления как в пункте 2, но с вычислением intercept. Учесть, что изменение коэффициентов должно производиться на каждом шаге одновременно (то есть изменение одного коэффициента не должно влиять на изменение другого во время одной итерации).

# %%
# model => y_hat = B0 + B1 * X
def mse2_(B0, B1, y , x , n):
    return (np.sum((B0 + B1 * x - y) ** 2) / n)

# %%
B0 = 100
B1 = 0.1
alpha = 1e-6
x = zp
y = ks

for i in range(3000):
    B1 -= alpha * (2 / n) * np.sum((B0 + B1 * x - y) * x)
    B0_ = B0
    B0 = np.mean(y) - B1 * np.mean(x)
    if i % 500 == 0:
        print(f'Iteration: {i}, B0 = {B0_}, B1 = {B1}, mse = {mse2_(B0_, B1, y=y, x=x, n=n)}')
# Out:
# Iteration: 0, B0 = 100, B1 = 0.23924808, mse = 369261.42687307834
# Iteration: 500, B0 = 451.4696638518714, B1 = 2.549125287182398, mse = 6488.239118976409
# Iteration: 1000, B0 = 444.3960495672612, B1 = 2.6183972281465313, mse = 6470.430232318689
# Iteration: 1500, B0 = 444.18391578387076, B1 = 2.6204746553751392, mse = 6470.414215594536
# Iteration: 2000, B0 = 444.1775540089358, B1 = 2.6205369562697016, mse = 6470.414201189626
# Iteration: 2500, B0 = 444.1773632228211, B1 = 2.6205388246391013, mse = 6470.414201176668
